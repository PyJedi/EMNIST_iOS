# %%
#@title
from google.colab import drive
drive.mount('/content/drive')

# %%
cd drive

# %%
cd My \Drive

# %%
cd /EMNIST/Saved_Models

# %%
# !pip3 install coremltools

# %%
import keras
from keras.models import load_model
from keras.utils import CustomObjectScope
from keras.initializers import glorot_uniform
import coremltools

model = load_model('emnist_model1.h5')
coreml_model = coremltools.converters.keras.convert(model)
coreml_model.save('emnist_model1.mlmodel')
print('Done!')

# %%
model = load_model('emnist_model2.h5')
coreml_model = coremltools.converters.keras.convert(model)
coreml_model.save('emnist_model2.mlmodel')
print('Done!')

# %%
model = load_model('emnist_model3.h5')
coreml_model = coremltools.converters.keras.convert(model)
coreml_model.save('emnist_model3.mlmodel')
print('Done!')

# %%
model = load_model('emnist_model4.h5')
coreml_model = coremltools.converters.keras.convert(model)
coreml_model.save('emnist_model4.mlmodel')
print('Done!')

# %%
model = load_model('emnist_model5.h5')
coreml_model = coremltools.converters.keras.convert(model)
coreml_model.save('emnist_model5.mlmodel')
print('Done!')

# %%
model = load_model('emnist_model6.h5')
coreml_model = coremltools.converters.keras.convert(model)
coreml_model.save('emnist_model6.mlmodel')
print('Done!')

# %%
model = load_model('emnist_model7.h5')
coreml_model = coremltools.converters.keras.convert(model)
coreml_model.save('emnist_model7.mlmodel')
print('Done!')

# %%
model = load_model('emnist_model8.h5')
coreml_model = coremltools.converters.keras.convert(model)
coreml_model.save('emnist_model8.mlmodel')
print('Done!')

# %%
model = load_model('emnist_model9.h5')
coreml_model = coremltools.converters.keras.convert(model)
coreml_model.save('emnist_model9.mlmodel')
print('Done!')
