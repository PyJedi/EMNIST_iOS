# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd drive

# %%
cd My \Drive

# %%
cd /EMNIST/coreML_Models

# %%
# !pip3 install coremltools

# %%
import coremltools

model_spec = coremltools.utils.load_spec('emnist_model1.mlmodel')
model_fp16_spec = coremltools.utils.convert_neural_network_spec_weights_to_fp16(model_spec)
coremltools.utils.save_spec(model_fp16_spec, 'emnist_model1_FP16.mlmodel')
print('Done!')

# %%
model_spec = coremltools.utils.load_spec('emnist_model2.mlmodel')
model_fp16_spec = coremltools.utils.convert_neural_network_spec_weights_to_fp16(model_spec)
coremltools.utils.save_spec(model_fp16_spec, 'emnist_model2_FP16.mlmodel')
print('Done!')

# %%
model_spec = coremltools.utils.load_spec('emnist_model3.mlmodel')
model_fp16_spec = coremltools.utils.convert_neural_network_spec_weights_to_fp16(model_spec)
coremltools.utils.save_spec(model_fp16_spec, 'emnist_model3_FP16.mlmodel')
print('Done!')

# %%
model_spec = coremltools.utils.load_spec('emnist_model4.mlmodel')
model_fp16_spec = coremltools.utils.convert_neural_network_spec_weights_to_fp16(model_spec)
coremltools.utils.save_spec(model_fp16_spec, 'emnist_model4_FP16.mlmodel')
print('Done!')

# %%
model_spec = coremltools.utils.load_spec('emnist_model5.mlmodel')
model_fp16_spec = coremltools.utils.convert_neural_network_spec_weights_to_fp16(model_spec)
coremltools.utils.save_spec(model_fp16_spec, 'emnist_model5_FP16.mlmodel')
print('Done!')

# %%
model_spec = coremltools.utils.load_spec('emnist_model6.mlmodel')
model_fp16_spec = coremltools.utils.convert_neural_network_spec_weights_to_fp16(model_spec)
coremltools.utils.save_spec(model_fp16_spec, 'emnist_model6_FP16.mlmodel')
print('Done!')

# %%
model_spec = coremltools.utils.load_spec('emnist_model7.mlmodel')
model_fp16_spec = coremltools.utils.convert_neural_network_spec_weights_to_fp16(model_spec)
coremltools.utils.save_spec(model_fp16_spec, 'emnist_model7_FP16.mlmodel')
print('Done!')

# %%
model_spec = coremltools.utils.load_spec('emnist_model8.mlmodel')
model_fp16_spec = coremltools.utils.convert_neural_network_spec_weights_to_fp16(model_spec)
coremltools.utils.save_spec(model_fp16_spec, 'emnist_model8_FP16.mlmodel')
print('Done!')

# %%
model_spec = coremltools.utils.load_spec('emnist_model9.mlmodel')
model_fp16_spec = coremltools.utils.convert_neural_network_spec_weights_to_fp16(model_spec)
coremltools.utils.save_spec(model_fp16_spec, 'emnist_model9_FP16.mlmodel')
print('Done!')
